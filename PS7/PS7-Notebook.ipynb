# %%
# Problem Set 7:
# Name:
# Collaborators:
# Time:

# %%
# setup notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2  
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Note:
# may wish to use random.seed() to give reproducible results during testing.

# %% [markdown]
# -----------------
# ## Some example Python/numpy syntax you might find useful

# %%
# create two vectors and plot
vec1 = np.random.random((100,))+np.linspace(0,1,100)
vec2 = np.random.random((100,))

plt.plot(vec1)
plt.plot(vec2)

# %%
# make a 2d array
twod_array = np.zeros((2,100)) * np.nan
twod_array[0,:] = vec1
twod_array[1,:] = vec2
# shortcut, useful sometimes
# twod_array = np.hstack((vec1,vec2))

plt.plot(np.mean(twod_array, axis=0),'k')  # try this with axis=1, how long is the result?
# note y-axis values on this plot vs the one above

# %% [markdown]
# -------------------
# # Problem 1-2 code tests:
# ## SimpleVirus

# %%
import ps7
# write your own test code here, e.g.:
sv = ps7.SimpleVirus(0.5,0.5)
# you may want to test the methods of SimpleVirus to make sure they do what is specified

# %% [markdown]
# ## SimplePatient

# %%
import ps7
maxBP = 0.9
cP = 0.3
nViruses = 30

startVirus = []
for iV in range(nViruses):
    startVirus.append(ps7.SimpleVirus(maxBP, cP))
# comment: you can replace the above three lines with a list comprehension:
#startViruses = [ps7.SimpleVirus(maxBP, cP) for iV in range(nViruses)]
sp = ps7.SimplePatient(startVirus, 100)

# This is the test code - does simplePatient behave as you like?
for iR in range(10):
    sp.update()
    print('After iteration %d, totalPop: %d' % (iR,sp.getTotalPop()))
    # may wish to print density above too.

# %% [markdown]
# ## Call simulationWithoutDrug

# %%
# write calls yourself to test this function

# recommend: call it once, plot result
# then call many times, plot averages

# %% [markdown]
# --------
# # Problem 2 plots go here

# %% [markdown]
# --------
# # Problem 3 answers go here
